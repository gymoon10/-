# %%
from keras import models, layers
from keras import Input
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers, initializers, regularizers, metrics
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import BatchNormalization, Conv2D, Activation, Dense, GlobalAveragePooling2D, MaxPooling2D, ZeroPadding2D, Add
 
import os
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# number of classes
K = 4
 
# input 
input_tensor = Input(shape=(224, 224, 3), dtype='float32', name='input')

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/44194558/147188626-25937b87-d254-45e0-89f5-1d79d00e4d50.png)

# %%
def conv1_layer(x):    
    x = ZeroPadding2D(padding=(3, 3))(x)
    x = Conv2D(64, (7, 7), strides=(2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = ZeroPadding2D(padding=(1,1))(x)
 
    return x

# %%
x = conv1_layer(input_tensor)
print(x.shape)
# Out:
# (None, 114, 114, 64)

# %%
def conv2_layer(x):         
    x = MaxPooling2D((3, 3), 2)(x)     
    
    # Network output F(x)에 더해줌
    shortcut = x
    print('shorcut :', shortcut.shape)
    
    # 총 3개의 block으로 구성
    for i in range(3):
        if (i == 0):  # 각 stage마다 첫 번째 block은 이전 stage에서 받아온 tensor의 dimension을 증가시켜야 함
            x = Conv2D(64, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            
            # Add 연산을 사용할 수 있도록 shortcut에 conv연산을 적용시켜 downsampling
            shortcut = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(shortcut)    
            print('shorcut after 1x1 Conv :', shortcut.shape)        
            x = BatchNormalization()(x)
            print('F(x) :', x.shape)
            shortcut = BatchNormalization()(shortcut)
            
            # F(x) + x
            x = Add()([x, shortcut])
            x = Activation('relu')(x)
            print('F(x) + x :', x.shape)
            
            shortcut = x  # 이후 단계에서 shortcut은 언제나 256 채널로 유지됨
        
        else:
            x = Conv2D(64, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
            
            # F(x) + x
            x = Add()([x, shortcut])   
            x = Activation('relu')(x)  
 
            shortcut = x        
    
    return x

# %%
x = conv2_layer(x)
print(x.shape)
# Out:
# shorcut : (None, 56, 56, 64)
# shorcut after 1x1 Conv : (None, 56, 56, 256)
# F(x) : (None, 56, 56, 256)
# F(x) + x : (None, 56, 56, 256)
# (None, 56, 56, 256)

# %%
def conv3_layer(x):        
    shortcut = x    
    print('shorcut :', shortcut.shape)
    
    # 4개 block
    for i in range(4):     
        if(i == 0):            
            x = Conv2D(128, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            # downsampling
            shortcut = Conv2D(512, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            print('shorcut after 1x1 Conv :', shortcut.shape) 
            x = BatchNormalization()(x)
            print('F(x) :', x.shape)
            shortcut = BatchNormalization()(shortcut)            
            
            # skip-conn
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)  
            print('F(x) + x :', x.shape)  
 
            shortcut = x  # 이후 단계에서 계속 512 채널 유지 (downsampling 불필요)      
        
        else:
            x = Conv2D(128, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])     
            x = Activation('relu')(x)
 
            shortcut = x      
            
    return x

# %%
x = conv3_layer(x)
print(x.shape)
# Out:
# shorcut : (None, 56, 56, 256)
# shorcut after 1x1 Conv : (None, 28, 28, 512)
# F(x) : (None, 28, 28, 512)
# F(x) + x : (None, 28, 28, 512)
# (None, 28, 28, 512)

# %%
def conv4_layer(x):
    shortcut = x    
    print('shorcut :', shortcut.shape)    
  
    for i in range(6):     
        if(i == 0):            
            x = Conv2D(256, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(1024, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(1024, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            print('shorcut after 1x1 Conv :', shortcut.shape)
            x = BatchNormalization()(x)
            print('F(x) :', x.shape)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)
            print('F(x) + x :', x.shape)
 
            shortcut = x               
        
        else:
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(1024, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)
 
            shortcut = x      
 
    return x

# %%
x = conv4_layer(x)
print(x.shape)
# Out:
# shorcut : (None, 28, 28, 512)
# shorcut after 1x1 Conv : (None, 14, 14, 1024)
# F(x) : (None, 14, 14, 1024)
# F(x) + x : (None, 14, 14, 1024)
# (None, 14, 14, 1024)

# %%
def conv5_layer(x):
    shortcut = x   
    print('shorcut :', shortcut.shape)  
  
    for i in range(3):     
        if(i == 0):            
            x = Conv2D(512, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(2048, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(2048, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            print('shorcut after 1x1 Conv :', shortcut.shape)
            x = BatchNormalization()(x)
            print('F(x) :', x.shape)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])  
            x = Activation('relu')(x)      
            print('F(x) + x :', x.shape)
 
            shortcut = x               
        
        else:
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(2048, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)           
            
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)       
 
            shortcut = x                  
 
    return x

# %%
x = conv5_layer(x)
print(x.shape)
# Out:
# shorcut : (None, 14, 14, 1024)
# shorcut after 1x1 Conv : (None, 7, 7, 2048)
# F(x) : (None, 7, 7, 2048)
# F(x) + x : (None, 7, 7, 2048)
# (None, 7, 7, 2048)

# %%
x = GlobalAveragePooling2D()(x)
output_tensor = Dense(K, activation='softmax')(x)

# %%
print(output_tensor.shape)
# Out:
# (None, 4)

# %%
resnet50 = Model(input_tensor, output_tensor)
resnet50.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_10 (ZeroPadding  (None, 230, 230, 3)  0          ['input[0][0]']
#  2D)
#
#  conv2d_29 (Conv2D)             (None, 112, 112, 64  9472        ['zero_padding2d_10[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 112, 112, 64  256        ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 112, 112, 64  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  zero_padding2d_11 (ZeroPadding  (None, 114, 114, 64  0          ['activation_25[0][0]']
#  2D)                            )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)  0           ['zero_padding2d_11[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 56, 56, 64)   4160        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 56, 56, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_26[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 56, 56, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 256)  16640       ['activation_27[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 56, 56, 256)  16640       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_31[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_28 (Activation)     (None, 56, 56, 256)  0           ['add_7[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 56, 56, 64)   16448       ['activation_28[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 56, 56, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_29[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 56, 56, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 56, 56, 256)  16640       ['activation_30[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_35[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_31 (Activation)     (None, 56, 56, 256)  0           ['add_8[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 56, 56, 64)   16448       ['activation_31[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 56, 56, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_32[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 56, 56, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 56, 56, 256)  16640       ['activation_33[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_38[0][0]',
#                                                                   'activation_31[0][0]']
#
#  activation_34 (Activation)     (None, 56, 56, 256)  0           ['add_9[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 28, 28, 128)  32896       ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 28, 28, 128)  512        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_35[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 28, 28, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_36[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_34[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_43[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_41[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_37 (Activation)     (None, 28, 28, 512)  0           ['add_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_37[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 28, 28, 128)  512        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_38[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 28, 28, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_39[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_46[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_45[0][0]',
#                                                                   'activation_37[0][0]']
#
#  activation_40 (Activation)     (None, 28, 28, 512)  0           ['add_11[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_40[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 28, 28, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_41[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 28, 28, 128)  512        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_42[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_49[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_48[0][0]',
#                                                                   'activation_40[0][0]']
#
#  activation_43 (Activation)     (None, 28, 28, 512)  0           ['add_12[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_43[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 28, 28, 128)  512        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_44[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 28, 28, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_45[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_52[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_51[0][0]',
#                                                                   'activation_43[0][0]']
#
#  activation_46 (Activation)     (None, 28, 28, 512)  0           ['add_13[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 256)  131328      ['activation_46[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_47[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_48[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_46[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  batch_normalization_55 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  add_14 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_54[0][0]',
#                                 )                                 'batch_normalization_55[0][0]']
#
#  activation_49 (Activation)     (None, 14, 14, 1024  0           ['add_14[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_49[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_50[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_51[0][0]']
#                                 )
#
#  batch_normalization_58 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  add_15 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_58[0][0]',
#                                 )                                 'activation_49[0][0]']
#
#  activation_52 (Activation)     (None, 14, 14, 1024  0           ['add_15[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_52[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_53[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_54[0][0]']
#                                 )
#
#  batch_normalization_61 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  add_16 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_61[0][0]',
#                                 )                                 'activation_52[0][0]']
#
#  activation_55 (Activation)     (None, 14, 14, 1024  0           ['add_16[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_55[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_56[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_57[0][0]']
#                                 )
#
#  batch_normalization_64 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_65[0][0]']
#  ormalization)                  )
#
#  add_17 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_64[0][0]',
#                                 )                                 'activation_55[0][0]']
#
#  activation_58 (Activation)     (None, 14, 14, 1024  0           ['add_17[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_58[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_59[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_66[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_60[0][0]']
#                                 )
#
#  batch_normalization_67 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_68[0][0]']
#  ormalization)                  )
#
#  add_18 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_67[0][0]',
#                                 )                                 'activation_58[0][0]']
#
#  activation_61 (Activation)     (None, 14, 14, 1024  0           ['add_18[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_61[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_68[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_62[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_63[0][0]']
#                                 )
#
#  batch_normalization_70 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_71[0][0]']
#  ormalization)                  )
#
#  add_19 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_70[0][0]',
#                                 )                                 'activation_61[0][0]']
#
#  activation_64 (Activation)     (None, 14, 14, 1024  0           ['add_19[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 7, 7, 512)    524800      ['activation_64[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_72[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_71[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_65[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_72[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_66[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_64[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_74[0][0]']
#  ormalization)
#
#  batch_normalization_74 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_75[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_73[0][0]',
#                                                                   'batch_normalization_74[0][0]']
#
#  activation_67 (Activation)     (None, 7, 7, 2048)   0           ['add_20[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_67[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_68[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_76[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_69[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_78[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_77[0][0]',
#                                                                   'activation_67[0][0]']
#
#  activation_70 (Activation)     (None, 7, 7, 2048)   0           ['add_21[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_70[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_79[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_78[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_71[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_79[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_72[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_81[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_80[0][0]',
#                                                                   'activation_70[0][0]']
#
#  activation_73 (Activation)     (None, 7, 7, 2048)   0           ['add_22[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['activation_73[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            8196        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 23,595,908
# Trainable params: 23,542,788
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
